# %%
import numpy as np

# %%
class BTNode:
  def __init__(self, elem):
    self.elem = elem
    self.right = None
    self.left = None

# %%
def inorder(root):
  if root == None:
    return

  inorder(root.left)
  print(root.elem, end = ' ')
  inorder(root.right)

# %%
def tree_construction(arr, i = 1):
  if i>=len(arr) or arr[i] == None:
    return None
  p = BTNode(arr[i])
  p.left = tree_construction(arr, 2*i)
  p.right = tree_construction(arr, 2*i+1)
  return p


root2 = tree_construction([None, 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', None, None, None, 'I', 'J', None, 'k'])
inorder(root2)
# Out:
# H D B E A I F J C G k

# %% [markdown]
# Task 1

# %%
def convert_mirror(root):
  if root.right==None and root.left==None:
    return root
  elif root.right!=None and root.left==None:
    c=root.right
    root.right=None
    root.left=c
  elif root.right==None and root.left!=None:
    c=root.left
    root.left=None
    root.right=c
  else:
    c=root.right
    root.right=root.left
    root.left=c
    convert_mirror(root.left)
    convert_mirror(root.right)

  #pass
  return root


#DRIVER CODE
root = BTNode(10)
n1 = BTNode(20)
n2 = BTNode(30)
n3 = BTNode(40)
n4 = BTNode(60)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  40 20 60 10 30
print()

root2 = convert_mirror(root)
print('Mirrored Tree Inorder Traversal: ', end = ' ')
inorder(root2) #Mirrored Tree Inorder Traversal:  30 10 60 20 40
# Out:
# Given Tree Inorder Traversal:  40 20 60 10 30
# Mirrored Tree Inorder Traversal:  30 10 60 20 40

# %% [markdown]
# Task 2

# %%
def largest_lvl(root,level,max_values):
    if root==None:
      return
    else:
        if root.left!=None and root.right!=None:
          print(root.left.elem,root.elem,root.right.elem)
        elif root.left==None and root.right!=None:
          print(None,root.elem,root.right.elem)
        if level not in max_values or root.elem > max_values[level]:
            max_values[level] = root.elem
        largest_lvl(root.left, level + 1, max_values)
        largest_lvl(root.right, level + 1, max_values)

        return max_values

def largest_level(root):
  d= largest_lvl(root, 0,{})
  for i in d.keys():
    print(d[i])
    # print(i.values())
#DRIVER CODE
root = tree_construction([None, 4,9,2,3,5,None,7])
print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  3 9 5 4 2 7
print()
print('Level Wise Largest Value: ', end = ' ')
print(largest_level(root)) #Level Wise Largest Value:  {0: 4, 1: 9, 2: 7}
# Out:
# Given Tree Inorder Traversal:  3 9 5 4 2 7
# Level Wise Largest Value:  9 4 2
# 3 9 5
# None 2 7
# 4
# 9
# 7
# None

# %% [markdown]
# Task 3

# %%
def inorder_successor(root, x):
  def insuc(root):
    if root.left==None:
      return root
    else:
      return insuc(root.left)
  return insuc(x.right)

#DRIVER CODE
root = BTNode(20)
n1 = BTNode(8)
n2 = BTNode(22)
n3 = BTNode(4)
n4 = BTNode(12)
n5 = BTNode(10)
n6 = BTNode(14)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

n4.left = n5
n4.right = n6

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  4 8 10 12 14 20 22
print()

x = n1
print(f'Inorder successor of node {x.elem}: {inorder_successor(root, x).elem}') #Inorder successor of node 8: 10
# Out:
# Given Tree Inorder Traversal:  4 8 10 12 14 20 22
# Inorder successor of node 8: 10

# %% [markdown]
# Task 4

# %%
def kth_smallest(root,k,i=0):
  len=2**(height(root))
  arr=np.array([None]*2**(height(root)))
  tree_to_array(root,arr)

  return BTNode(arr[k-1])

#DRIVER CODE
root = tree_construction([None, 9,5,11,4,7,None,12,None,None,6,8,None,None,None,None])
print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root)
print()
k = 4
print(kth_smallest(root,k).elem)
# Out:
# Given Tree Inorder Traversal:  4 5 6 7 8 9 11 12
# [4 5 6 7 8 9 11 12 None None None None None None None None]
# 7

# %% [markdown]
# Bonus

# %%
#WRITE THE FUNCTION AND DRIVER CODE BY YOURSELF
def neutralizer2(root,lv,i):
  if root:
    if lv%2==0:
      i[0]+=root.elem
    elif lv%2!=0:
      i[0]-=root.elem
    neutralizer2(root.left,lv+1,i)
    neutralizer2(root.right,lv+1,i)
  return i[0]
def neutralizer(root):
  print(neutralizer2(root,0,np.array([0])))
  pass
root=tree_construction([None,1,2,3,4,None,5,6,None,None,None,None,7,8,None,None])
print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root)
print()
neutralizer(root)
# Out:
# Given Tree Inorder Traversal:  4 2 1 7 5 8 3 6
# -4

# %%
def kth_small(root,k,i=np.array([0])):
  # if root==None or i[0]>=k:
  #   print("NONE")
  #   return
  if root or i[0]<=k:
    return kth_small(root.left,k,i)
    i[0]+=1
    if i[0]==k:
      print(i)
      return root
    return kth_small(root.right,k,i)

#DRIVER CODE
root = tree_construction([None, 9,5,11,4,7,None,12,None,None,6,8,None,None,None,None])
print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root)
print()
k = 4
print(kth_small(root,k).elem)

# %%
def height(node):
    if node is None:
        return 0
    else:

        # Compute the height of each subtree
        lheight = height(node.left)
        # print("l:",lheight)
        rheight = height(node.right)
        # print("b:",lheight,"root",root.elem,rheight)
        # Use the larger one
        if lheight > rheight:
            return lheight+1
        else:
            # if lheight==rheight:
              # print("left:",lheight,"root::::",root.elem,rheight+1)
            return rheight+1

root = tree_construction([None, 9,5,11,4,7,None,12,None,None,6,8,None,None,None,None])
def tree_to_array(root,arr,i=np.array([0])):
    if root is None:
        return

    tree_to_array(root.left, arr, i)

    arr[i[0]] = root.elem
    i[0] += 1
    tree_to_array(root.right, arr, i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-17840ed65a57> in <cell line: 19>()
#      17             return rheight+1
#      18
# ---> 19 root = tree_construction([None, 9,5,11,4,7,None,12,None,None,6,8,None,None,None,None])
#      20 def tree_to_array(root,arr,i=np.array([0])):
#      21     if root is None:
#
# NameError: name 'tree_construction' is not defined

# %%
def largest_lvl(root,level,max_values):
    if root==None:
      return
    else:
        # if root.left!=None and root.right!=None:
        #   print(root.left.elem,root.elem,root.right.elem)
        # elif root.left==None and root.right!=None:
        #   print(None,root.elem,root.right.elem)
        if level not in max_values or root.elem > max_values[level]:
            max_values[level] = root.elem
        largest_lvl(root.left, level + 1, max_values)
        largest_lvl(root.right, level + 1, max_values)

        return max_values

def largest_level(root):
  d= largest_lvl(root, 0,{})
  for i in d.keys():
    print(d[i],end=" ")
  return d
    # print(i.values())
#DRIVER CODE
root = tree_construction([None, 4,9,2,3,5,None,7])
print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  3 9 5 4 2 7
print()
print('Level Wise Largest Value: ', end = ' ')
print(largest_level(root))
# Out:
# Given Tree Inorder Traversal:  3 9 5 4 2 7
# Level Wise Largest Value:  4 9 7 {0: 4, 1: 9, 2: 7}

# %%
def is_symmetric(root1,root2):
  if root1==None and root2!=None or root1!=None and root2==None:
    return False
  elif root1 and root2:
    if root1.elem==root2.elem:
      return True and is_symmetric(root1.left,root2.left) and is_symmetric(root1.right,root2.right)
    else:
      return False
  return True
root1 = tree_construction([None, 4,9,2,3,5,None,8])
root2 = tree_construction([None, 4,9,2,3,5,None,8])
print(is_symmetric(root1,root2))
# Out:
# True

# %%
def is_balanced(root):
  if root:
    if abs(height(root.left)-height(root.right))<=1:
      return abs(height(root.left)-height(root.left))
    else:
      return 0

root = tree_construction([None, 4,9,2,3,5,None,8])
print(is_balanced(root))
# Out:
# 0

# %%
def height(root):
  if root==None:
    return -1
  else:
    lheight=height(root.left)
    rheight=height(root.right)
    if lheight<rheight:
      return rheight+1
    else:
      return lheight+1
height(root)
# Out:
# 2

# %%
def bintolist(root,l):
    if root:
        bintolist(root.left,l)
        l.append(root.elem)
        bintolist(root.right,l)
    l.sort()
    return l
def listobin(l,start,end):
    if len(l)>=1:
        print(l)
        left=len(l)//2-1
        mid=len(l)//2
        right=len(l)//2+1
        root=BTNode(l[mid])
        inorder(root)
        print(root.elem)
        root.left=listobin(l[:mid],)

        root.right=listobin(l[right:])
    return root
def binaryTreeToBST( root):
    l=bintolist(root,l=[])
    return listobin(l)
root = tree_construction([None, 1,2,3,4,5,6,7])
inorder(binaryTreeToBST(root))
# Out:
# [1, 2, 3, 4, 5, 6, 7]
# 4 4
# [1, 2, 3]
# 2 2
# [1]
# 1 1
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-cf0822e6e7ae> in <cell line: 25>()
#      23     return listobin(l)
#      24 root = tree_construction([None, 1,2,3,4,5,6,7])
# ---> 25 inorder(binaryTreeToBST(root))
#
# <ipython-input-12-cf0822e6e7ae> in binaryTreeToBST(root)
#      21 def binaryTreeToBST( root):
#      22     l=bintolist(root,l=[])
# ---> 23     return listobin(l)
#      24 root = tree_construction([None, 1,2,3,4,5,6,7])
#      25 inorder(binaryTreeToBST(root))
#
# <ipython-input-12-cf0822e6e7ae> in listobin(l)
#      15         inorder(root)
#      16         print(root.elem)
# ---> 17         root.left=listobin(l[:mid])
#      18
#      19         root.right=listobin(l[right:])
#
# <ipython-input-12-cf0822e6e7ae> in listobin(l)
#      15         inorder(root)
# ...
